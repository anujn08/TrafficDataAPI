# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os

# %%
path = 'D:\Anuj\Here\Ludhiana_New25_6_23'   
save_path = 'D:\\Anuj\\Here\\Ludhiana_New25_6_23\\visualization'   

df=pd.read_csv("example4.csv")
df.head(10)
# Out:
#    Unnamed: 0           names  speed  \
# 0           0      Brown Road  17.00
# 1           1  Janakpuri Road  18.31
# 2           2  Janakpuri Road  18.31
# 3           3  Janakpuri Road  18.31
# 4           4  Janakpuri Road  18.31
# 5           5  Janakpuri Road  18.31
# 6           6  Janakpuri Road  18.31
# 7           7  Janakpuri Road  18.31
# 8           8  Janakpuri Road  18.31
# 9           9  Janakpuri Road  18.31
#
#                                   lattitude  \
# 0             [30.90879, 30.90871, 30.9086]
# 1             [30.9086, 30.90848, 30.90782]
# 2                      [30.90782, 30.90761]
# 3                      [30.90761, 30.90742]
# 4            [30.90742, 30.90728, 30.90717]
# 5  [30.90717, 30.90706, 30.90692, 30.90685]
# 6            [30.90685, 30.90674, 30.90661]
# 7                      [30.90661, 30.90653]
# 8            [30.90653, 30.90634, 30.90624]
# 9                      [30.90624, 30.90596]
#
# ...

# %%
def getTime():
    now = datetime.now()
    current_time = now.strftime("%d-%b-%Y-%H-%M")
    return current_time

# %%
def visualize(path):
    df=pd.read_csv(path)
    fig=plt.figure(figsize=(14,8.0))
    plt.rcParams['axes.facecolor'] = 'white'
    plt.grid(False)

    #print("Lattitude=",len(df["lattitude"]))

    for i in range(len(df["lattitude"])):
        x=df["lattitude"][i].split(',')
        x[0],x[-1]=x[0][1:],x[-1][:-1]

        y=df["Longitude"][i].split(',')
        y[0],y[-1]=y[0][1:],y[-1][:-1]

        lat = [eval(j) for j in x]
        lon = [eval(j) for j in y]

        speed=df["speed"]

        if float(speed[i]) == 0:
            plt.plot(lon,lat,c='gray',linewidth=5)
        elif float(speed[i]) < 10:
            plt.plot(lon,lat,c='brown',linewidth=5)
        elif float(speed[i]) < 15:
            plt.plot(lon,lat,c='orange',linewidth=3)
        elif float(speed[i]) < 20:
            plt.plot(lon,lat,c='yellow',linewidth=2)
        else: # more than 20.
            plt.plot(lon,lat,c='green',linewidth=1)

    plt.axis('on')
    plt.title("SP "+getTime())
    #plt.legend()
    timeStr=getTime()
    saveFileName="speedProfiles"+timeStr+".png"
    #plt.text(77.60, 13.03, "Ludhiana "+timeStr, fontdict=font)
    plt.savefig(os.path.join(save_path, saveFileName),dpi=500)
    print("Visualized "+path)

#visualize()

# %%
for i in os.listdir(path):
    if i.endswith(".csv"):
        print(path+"\\"+i)
        visualize(path+"\\"+i)
# Out:
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-00.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-00.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-01.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-01.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-02.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-02.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-03.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-03.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-04.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-04.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-05.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-05.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-06.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-06.csv
# D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-07.csv
# Visualized D:\Anuj\Here\Ludhiana_New25_6_23\26-Jun-2023-20-07.csv
# ...
